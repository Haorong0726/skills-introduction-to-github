# %% [markdown]
# <a href="https://colab.research.google.com/github/Haorong0726/skills-introduction-to-github/blob/main/_downloads/44a84f8c1764dbf61662d306ff9ed43a/chatbot_tutorial_new_version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import wandb

wandb.login()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: youjie020726 (youjie020726-new-york-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# Chatbot Tutorial
# ================
#
# **Author:** [Matthew Inkawhich](https://github.com/MatthewInkawhich)

# %% [markdown]
# In this tutorial, we explore a fun and interesting use-case of recurrent
# sequence-to-sequence models. We will train a simple chatbot using movie
# scripts from the [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html).
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company's IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google's [Neural
# Conversational Model](https://arxiv.org/abs/1506.05869), which marks a
# large step towards multi-domain generative conversational models. In
# this tutorial, we will implement this kind of model in PyTorch.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/bot.png){.align-center}
#
# ``` {.python}
# > hello?
# Bot: hello .
# > where am I?
# Bot: you re in a hospital .
# > who are you?
# Bot: i m a lawyer .
# > how are you doing?
# Bot: i m fine .
# > are you my friend?
# Bot: no .
# > you're under arrest
# Bot: i m trying to help you !
# > i'm just kidding
# Bot: i m sorry .
# > where are you from?
# Bot: san francisco .
# > it's time for me to leave
# Bot: i know .
# > goodbye
# Bot: goodbye .
# ```
#
# **Tutorial Highlights**
#
# -   Handle loading and preprocessing of [Cornell Movie-Dialogs
#     Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
#     dataset
# -   Implement a sequence-to-sequence model with [Luong attention
#     mechanism(s)](https://arxiv.org/abs/1508.04025)
# -   Jointly train encoder and decoder models using mini-batches
# -   Implement greedy-search decoding module
# -   Interact with trained chatbot
#
# **Acknowledgments**
#
# This tutorial borrows code from the following sources:
#
# 1)  Yuan-Kuei Wu's pytorch-chatbot implementation:
#     <https://github.com/ywk991112/pytorch-chatbot>
# 2)  Sean Robertson's practical-pytorch seq2seq-translation example:
#     <https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation>
# 3)  FloydHub Cornell Movie Corpus preprocessing code:
#     <https://github.com/floydhub/textutil-preprocess-cornell-movie-corpus>

# %% [markdown]
# Preparations
# ============
#
# To get started,
# [download](https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip)
# the Movie-Dialogs Corpus zip file.

# %%
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json
from torch.profiler import profile, record_function, ProfilerActivity


# If the current `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__ is available,
# we will use it. Otherwise, we use the CPU.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# Load & Preprocess Data
# ======================
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
# is a rich dataset of movie character dialog:
#
# -   220,579 conversational exchanges between 10,292 pairs of movie
#     characters
# -   9,035 characters from 617 movies
# -   304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we'll take a look at some lines of our datafile to see the
# original format.

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("/content/drive/MyDrive/data", corpus_name)
def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)
printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %% [markdown]
# Create formatted data file
# ==========================
#
# For convenience, we\'ll create a nicely formatted data file in which
# each line contains a tab-separated *query sentence* and a *response
# sentence* pair.
#
# The following functions facilitate the parsing of the raw
# `utterances.jsonl` data file.
#
# -   `loadLinesAndConversations` splits each line of the file into a
#     dictionary of lines with fields: `lineID`, `characterID`, and text
#     and then groups them into conversations with fields:
#     `conversationID`, `movieID`, and lines.
# -   `extractSentencePairs` extracts pairs of sentences from
#     conversations

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we'll call these functions and create the file. We'll call it
# `formatted_movie_lines.txt`.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %% [markdown]
# Load and trim data
# ==================
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a `Voc` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (`addWord`), adding all words in a sentence (`addSentence`)
# and trimming infrequently seen words (`trim`). More on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# `unicodeToAscii`. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (`normalizeString`). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the `MAX_LENGTH` threshold
# (`filterPairs`).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True if both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using the ``filterPair`` condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1)  Trim words used under `MIN_COUNT` threshold using the `voc.trim`
#     function.
# 2)  Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %% [markdown]
# Prepare Data for Models
# =======================
#
# Although we have put a great deal of effort into preparing and massaging
# our data into a nice vocabulary object and list of sentence pairs, our
# models will ultimately expect numerical torch tensors as inputs. One way
# to prepare the processed data for the models can be found in the
# [seq2seq translation
# tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html).
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you're interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max\_length, batch\_size)*, where sentences shorter than the
# *max\_length* are zero padded after an *EOS\_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(`indexesFromSentence`) and zero-pad, our tensor
# would have shape *(batch\_size, max\_length)* and indexing the first
# dimension would return a full sequence across all time-steps. However,
# we need to be able to index our batch along time, and across all
# sequences in the batch. Therefore, we transpose our input batch shape to
# *(max\_length, batch\_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the `zeroPadding` function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_batches.png){.align-center}
#
# The `inputVar` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of `lengths` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The `outputVar` function performs a similar function to `inputVar`, but
# instead of returning a `lengths` tensor, it returns a binary mask tensor
# and a maximum target sentence length. The binary mask tensor has the
# same shape as the output target tensor, but every element that is a
# *PAD\_token* is 0 and all others are 1.
#
# `batch2TrainData` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[  75,   85,   14,   26,   40],
#         [ 105,  364,   14,  710,   11],
#         [  22,  319,   14,   17,   14],
#         [ 167,   14,   20,   99,    2],
#         [  24,   11,   98,   22,    0],
#         [2866, 4361, 5717, 2890,    0],
#         [ 203,   85,   14,   14,    0],
#         [ 161,   14,    2,    2,    0],
#         [  10,    2,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([10,  9,  8,  8,  4])
# target_variable: tensor([[  34,   24,   20,  309,   11],
#         [ 140,   77,   98, 1044,  121],
#         [  14,   10, 2440,  217, 1274],
#         [   2,    2,   14,   14,   85],
#         [   0,    0,    2,    2,   14],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False, False,  True,  True,  True],
#         [False, False, False, False,  True]])
# max_target_len: 6

# %% [markdown]
# Define Models
# =============
#
# Seq2Seq Model
# -------------
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# [Sutskever et al.](https://arxiv.org/abs/1409.3215) discovered that by
# using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_ts.png){.align-center}
#
# Image source:
# <https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/>

# %% [markdown]
# Encoder
# =======
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an "output" vector
# and a "hidden state" vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by [Cho et al.](https://arxiv.org/pdf/1406.1078v3.pdf) in 2014.
# We will use a bidirectional variant of the GRU, meaning that there are
# essentially two independent RNNs: one that is fed the input sequence in
# normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/RNN-bidirectional.png){.align-center
# width="70.0%"}
#
# Image source: <https://colah.github.io/posts/2015-09-NN-Types-FP/>
#
# Note that an `embedding` layer is used to encode our word indices in an
# arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden\_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# `nn.utils.rnn.pack_padded_sequence` and
# `nn.utils.rnn.pad_packed_sequence` respectively.
#
# **Computation Graph:**
#
# > 1)  Convert word indexes to embeddings.
# > 2)  Pack padded batch of sequences for RNN module.
# > 3)  Forward pass through GRU.
# > 4)  Unpack padding.
# > 5)  Sum bidirectional GRU outputs.
# > 6)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_seq`: batch of input sentences; shape=*(max\_length,
#     batch\_size)*
# -   `input_lengths`: list of sentence lengths corresponding to each
#     sentence in the batch; shape=*(batch\_size)*
# -   `hidden`: hidden state; shape=*(n\_layers x num\_directions,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `outputs`: output features from the last hidden layer of the GRU
#     (sum of bidirectional outputs); shape=*(max\_length, batch\_size,
#     hidden\_size)*
# -   `hidden`: updated hidden state from GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Decoder
# =======
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder's context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS\_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence's meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, [Bahdanau et al.](https://arxiv.org/abs/1409.0473)
# created an "attention mechanism" that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder's current
# hidden state and the encoder's outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. [Sean
# Robertson's](https://github.com/spro) figure describes this very well:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/attn2.png){.align-center}
#
# [Luong et al.](https://arxiv.org/abs/1508.04025) improved upon Bahdanau
# et al.'s groundwork by creating "Global attention". The key difference
# is that with "Global attention", we consider all of the encoder's hidden
# states, as opposed to Bahdanau et al.'s "Local attention", which only
# considers the encoder's hidden state from the current time step. Another
# difference is that with "Global attention", we calculate attention
# weights, or energies, using the hidden state of the decoder from the
# current time step only. Bahdanau et al.'s attention calculation requires
# knowledge of the decoder's state from the previous time step. Also,
# Luong et al. provides various methods to calculate the attention
# energies between the encoder output and decoder output which are called
# "score functions":
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/scores.png){.align-center
# width="60.0%"}
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ = all encoder
# states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the "Attention Layer" as a
# separate `nn.Module` called `Attn`. The output of this module is a
# softmax normalized weights tensor of shape *(batch\_size, 1,
# max\_length)*.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/global_attn.png){.align-center
# width="60.0%"}

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch\_size, hidden\_size)*.
#
# **Computation Graph:**
#
# > 1)  Get embedding of current input word.
# > 2)  Forward through unidirectional GRU.
# > 3)  Calculate attention weights from the current GRU output from (2).
# > 4)  Multiply attention weights to encoder outputs to get new
# >     \"weighted sum\" context vector.
# > 5)  Concatenate weighted context vector and GRU output using Luong
# >     eq. 5.
# > 6)  Predict next word using Luong eq. 6 (without softmax).
# > 7)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_step`: one time step (one word) of input sequence batch;
#     shape=*(1, batch\_size)*
# -   `last_hidden`: final hidden layer of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*
# -   `encoder_outputs`: encoder model's output; shape=*(max\_length,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `output`: softmax normalized tensor giving probabilities of each
#     word being the correct next word in the decoded sequence;
#     shape=*(batch\_size, voc.num\_words)*
# -   `hidden`: final hidden state of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# Define Training Procedure
# =========================
#
# Masked loss
# -----------
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# `maskNLLLoss` to calculate our loss based on our decoder's output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# Single training iteration
# =========================
#
# The `train` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -   The first trick is using **teacher forcing**. This means that at
#     some probability, set by `teacher_forcing_ratio`, we use the current
#     target word as the decoder's next input rather than using the
#     decoder's current guess. This technique acts as training wheels for
#     the decoder, aiding in more efficient training. However, teacher
#     forcing can lead to model instability during inference, as the
#     decoder may not have a sufficient chance to truly craft its own
#     output sequences during training. Thus, we must be mindful of how we
#     are setting the `teacher_forcing_ratio`, and not be fooled by fast
#     convergence.
# -   The second trick that we implement is **gradient clipping**. This is
#     a commonly used technique for countering the "exploding gradient"
#     problem. In essence, by clipping or thresholding gradients to a
#     maximum value, we prevent the gradients from growing exponentially
#     and either overflow (NaN), or overshoot steep cliffs in the cost
#     function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/grad_clip.png){.align-center
# width="60.0%"}
#
# Image source: Goodfellow et al. *Deep Learning*. 2016.
# <https://www.deeplearningbook.org/>
#
# **Sequence of Operations:**
#
# > 1)  Forward pass entire input batch through encoder.
# > 2)  Initialize decoder inputs as SOS\_token, and hidden state as the
# >     encoder\'s final hidden state.
# > 3)  Forward input batch sequence through decoder one time step at a
# >     time.
# > 4)  If teacher forcing: set next decoder input as the current target;
# >     else: set next decoder input as current decoder output.
# > 5)  Calculate and accumulate loss.
# > 6)  Perform backpropagation.
# > 7)  Clip gradients.
# > 8)  Update encoder and decoder model parameters.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, teacher_forcing_ratio, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# Training iterations
# ===================
#
# It is finally time to tie the full training procedure together with the
# data. The `trainIters` function is responsible for running
# `n_iterations` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the `train` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder `state_dicts` (parameters), the
# optimizers' `state_dicts`, the loss, the iteration, etc. Saving the
# model in this way will give us the ultimate flexibility with the
# checkpoint. After loading a checkpoint, we will be able to use the model
# parameters to run inference, or we can continue training right where we
# left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers,
               decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename, teacher_forcing_ratio):

    config = wandb.config
    wandb.log({
        "Learning Rate": config.learning_rate,
        "Decoder Learning Ratio": config.decoder_learning_ratio,
        "Clip": config.clip,
        "Teacher Forcing Ratio": config.teacher_forcing_ratio,
        "Optimizer": config.optimizer,
    })

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    best_loss = float('inf')
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip, teacher_forcing_ratio)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))

            wandb.log({
                "Iteration": iteration,
                "Loss": print_loss_avg})

            if print_loss_avg < best_loss:
                best_loss = print_loss_avg
                save_best_model(iteration, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                                save_dir, model_name, corpus_name, encoder_n_layers, decoder_n_layers, best_loss)

            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)

            checkpoint_path = os.path.join(directory, f'{iteration}_checkpoint.tar')

            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

            wandb.save(checkpoint_path)
    wandb.log({"loss": print_loss_avg})

# %%
def save_best_model(iteration, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding,
                    save_dir, model_name, corpus_name, encoder_n_layers, decoder_n_layers, best_loss):

    config = wandb.config
    hyperparam_str = f"lr{config.learning_rate}_clip{config.clip}_tf{config.teacher_forcing_ratio}_opt{config.optimizer}_dlr{config.decoder_learning_ratio}"

    directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(
        encoder_n_layers, decoder_n_layers, hidden_size))

    if not os.path.exists(directory):
        os.makedirs(directory)

    checkpoint_path = os.path.join(directory, f"best_model_{hyperparam_str}.pth")

    for file in os.listdir(directory):
        if file.startswith(f"best_model_{hyperparam_str}"):
            os.remove(os.path.join(directory, file))

    torch.save({
        'iteration': iteration,
        'en': encoder.state_dict(),
        'de': decoder.state_dict(),
        'en_opt': encoder_optimizer.state_dict(),
        'de_opt': decoder_optimizer.state_dict(),
        'loss': best_loss,
        'voc_dict': voc.__dict__,
        'embedding': embedding.state_dict()
    }, checkpoint_path)

    print(f"Best model saved at {checkpoint_path} with loss {best_loss:.4f}")

# %% [markdown]
# Define Evaluation
# =================
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# Greedy decoding
# ---------------
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from `decoder_output` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# `GreedySearchDecoder` class. When run, an object of this class takes an
# input sequence (`input_seq`) of shape *(input\_seq length, 1)*, a scalar
# input length (`input_length`) tensor, and a `max_length` to bound the
# response sentence length. The input sentence is evaluated using the
# following computational graph:
#
# **Computation Graph:**
#
# > 1)  Forward input through encoder model.
# >
# > 2)  Prepare encoder\'s final hidden layer to be first hidden input to
# >     the decoder.
# >
# > 3)  Initialize decoder\'s first input as SOS\_token.
# >
# > 4)  Initialize tensors to append decoded words to.
# >
# > 5)
# >
# >     Iteratively decode one word token at a time:
# >
# >     :   a)  Forward pass through decoder.
# >         b)  Obtain most likely word token and its softmax score.
# >         c)  Record token and score.
# >         d)  Prepare current token to be next decoder input.
# >
# > 6)  Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# Evaluate my text
# ================
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The `evaluate` function manages the
# low-level process of handling the input sentence. We first format the
# sentence as an input batch of word indexes with *batch\_size==1*. We do
# this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a `lengths` tensor which contains the length of
# our input sentence. In this case, `lengths` is scalar because we are
# only evaluating one sentence at a time (batch\_size==1). Next, we obtain
# the decoded response sentence tensor using our `GreedySearchDecoder`
# object (`searcher`). Finally, we convert the response's indexes to words
# and return the list of decoded words.
#
# `evaluateInput` acts as the user interface for our chatbot. When called,
# an input text field will spawn in which we can enter our query sentence.
# After typing our input sentence and pressing *Enter*, our text is
# normalized in the same way as our training data, and is ultimately fed
# to the `evaluate` function to obtain a decoded output sentence. We loop
# this process, so we can keep chatting with our bot until we enter either
# "q" or "quit".
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# Run Model
# =========
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000

# %% [markdown]
# Sample code to load from a checkpoint:
#
# ``` {.python}
# loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                     '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                     '{}_checkpoint.tar'.format(checkpoint_iter))
# ```

# %%
# Load model if a ``loadFilename`` is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Run Training
# ============
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the `trainIters` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have an accelerator, configure it to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c00d39ff97b5> in <cell line: 0>()
#      33 # Run training iterations
#      34 print("Starting Training!")
# ---> 35 trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
#      36            embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
#      37            print_every, save_every, clip, corpus_name, loadFilename)
#
# TypeError: trainIters() missing 1 required positional argument: 'teacher_forcing_ratio'

# %% [markdown]
# Run Evaluation
# ==============
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
# evaluateInput(encoder, decoder, searcher, voc)

# %%
sweep_config = {
    "method": "random",
    "metric": {"name": "loss", "goal": "minimize"},
    "parameters": {
        "learning_rate": {"values": [0.0001, 0.00025, 0.0005, 0.001]},
        "optimizer": {"values": ["adam", "sgd"]},
        "clip": {"values": [0, 25, 50, 100]},
        "teacher_forcing_ratio": {"values": [0, 0.5, 1.0]},
        "decoder_learning_ratio": {"values": [1.0, 3.0, 5.0, 10.0]}
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, project="chatbot_sweep_2")
# Out:
# Create sweep with ID: qjl60wv2
# Sweep URL: https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/sweeps/qjl60wv2

# %%
n_iteration = 4000
print_every = 1
save_every = 500

encoder.train()
decoder.train()

def train_sweep():
    wandb.init()
    config = wandb.config

    clip = config.clip
    teacher_forcing_ratio = config.teacher_forcing_ratio
    learning_rate = config.learning_rate
    decoder_learning_ratio = config.decoder_learning_ratio
    optimizer_type = config.optimizer

    if optimizer_type == "adam":
        encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
        decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    elif optimizer_type == "sgd":
        encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
        decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)

    print(f"Starting Training with {optimizer_type.upper()} optimizer!")
    trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename, teacher_forcing_ratio)


wandb.agent(sweep_id, function=train_sweep, count=10)
# Out:
# wandb: Agent Starting Run: wbyatvrn with config:
# wandb: 	clip: 0
# wandb: 	decoder_learning_ratio: 5
# wandb: 	learning_rate: 0.00025
# wandb: 	optimizer: sgd
# wandb: 	teacher_forcing_ratio: 0
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>/content/wandb/run-20250313_052449-wbyatvrn</code>
# Syncing run <strong><a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/runs/wbyatvrn' target="_blank">cool-sweep-7</a></strong> to <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/sweeps/qjl60wv2' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/sweeps/qjl60wv2</a>
#  View project at <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6</a>
#  View sweep at <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/sweeps/qjl60wv2' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/sweeps/qjl60wv2</a>
#  View run at <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/runs/wbyatvrn' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/runs/wbyatvrn</a>
# Starting Training with SGD optimizer!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 5.1142
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 5.1142
# Iteration: 2; Percent complete: 0.1%; Average loss: 5.4525
# Iteration: 3; Percent complete: 0.1%; Average loss: 5.1234
# Iteration: 4; Percent complete: 0.1%; Average loss: 5.3758
# Iteration: 5; Percent complete: 0.1%; Average loss: 5.3704
# Iteration: 6; Percent complete: 0.1%; Average loss: 5.3314
# Iteration: 7; Percent complete: 0.2%; Average loss: 5.2763
# Iteration: 8; Percent complete: 0.2%; Average loss: 5.1139
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 5.1139
# Iteration: 9; Percent complete: 0.2%; Average loss: 5.4089
# Iteration: 10; Percent complete: 0.2%; Average loss: 5.3469
# Iteration: 11; Percent complete: 0.3%; Average loss: 5.1845
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.1205
# Iteration: 13; Percent complete: 0.3%; Average loss: 4.9325
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.9325
# Iteration: 14; Percent complete: 0.4%; Average loss: 4.9822
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.2156
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.0661
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.3703
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.1556
# Iteration: 19; Percent complete: 0.5%; Average loss: 5.1089
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.1952
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.6249
# Iteration: 22; Percent complete: 0.5%; Average loss: 5.2633
# Iteration: 23; Percent complete: 0.6%; Average loss: 5.0784
# Iteration: 24; Percent complete: 0.6%; Average loss: 5.1294
# Iteration: 25; Percent complete: 0.6%; Average loss: 5.3503
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.9087
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.9087
# Iteration: 27; Percent complete: 0.7%; Average loss: 5.0971
# Iteration: 28; Percent complete: 0.7%; Average loss: 5.1149
# Iteration: 29; Percent complete: 0.7%; Average loss: 5.3508
# Iteration: 30; Percent complete: 0.8%; Average loss: 5.2509
# Iteration: 31; Percent complete: 0.8%; Average loss: 5.2368
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.9475
# Iteration: 33; Percent complete: 0.8%; Average loss: 5.1134
# Iteration: 34; Percent complete: 0.9%; Average loss: 5.2789
# Iteration: 35; Percent complete: 0.9%; Average loss: 5.3839
# Iteration: 36; Percent complete: 0.9%; Average loss: 5.1470
# Iteration: 37; Percent complete: 0.9%; Average loss: 5.3646
# Iteration: 38; Percent complete: 0.9%; Average loss: 5.1469
# Iteration: 39; Percent complete: 1.0%; Average loss: 5.3893
# Iteration: 40; Percent complete: 1.0%; Average loss: 5.3219
# Iteration: 41; Percent complete: 1.0%; Average loss: 5.2333
# Iteration: 42; Percent complete: 1.1%; Average loss: 5.2458
# Iteration: 43; Percent complete: 1.1%; Average loss: 5.3054
# Iteration: 44; Percent complete: 1.1%; Average loss: 5.2804
# Iteration: 45; Percent complete: 1.1%; Average loss: 5.0262
# Iteration: 46; Percent complete: 1.1%; Average loss: 5.1493
# Iteration: 47; Percent complete: 1.2%; Average loss: 5.3003
# Iteration: 48; Percent complete: 1.2%; Average loss: 5.3252
# Iteration: 49; Percent complete: 1.2%; Average loss: 5.1500
# Iteration: 50; Percent complete: 1.2%; Average loss: 5.0781
# Iteration: 51; Percent complete: 1.3%; Average loss: 5.2658
# Iteration: 52; Percent complete: 1.3%; Average loss: 5.2272
# Iteration: 53; Percent complete: 1.3%; Average loss: 5.0841
# Iteration: 54; Percent complete: 1.4%; Average loss: 5.1135
# Iteration: 55; Percent complete: 1.4%; Average loss: 5.3345
# Iteration: 56; Percent complete: 1.4%; Average loss: 5.4171
# Iteration: 57; Percent complete: 1.4%; Average loss: 5.1672
# Iteration: 58; Percent complete: 1.5%; Average loss: 5.2309
# Iteration: 59; Percent complete: 1.5%; Average loss: 5.1021
# Iteration: 60; Percent complete: 1.5%; Average loss: 5.1513
# Iteration: 61; Percent complete: 1.5%; Average loss: 5.5687
# Iteration: 62; Percent complete: 1.6%; Average loss: 5.2077
# Iteration: 63; Percent complete: 1.6%; Average loss: 5.3191
# Iteration: 64; Percent complete: 1.6%; Average loss: 5.0351
# Iteration: 65; Percent complete: 1.6%; Average loss: 5.0750
# Iteration: 66; Percent complete: 1.7%; Average loss: 5.4356
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.8064
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.8064
# Iteration: 68; Percent complete: 1.7%; Average loss: 5.1573
# Iteration: 69; Percent complete: 1.7%; Average loss: 5.2354
# Iteration: 70; Percent complete: 1.8%; Average loss: 5.5911
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.9339
# Iteration: 72; Percent complete: 1.8%; Average loss: 5.3785
# Iteration: 73; Percent complete: 1.8%; Average loss: 5.4886
# Iteration: 74; Percent complete: 1.8%; Average loss: 5.2239
# Iteration: 75; Percent complete: 1.9%; Average loss: 5.2568
# Iteration: 76; Percent complete: 1.9%; Average loss: 5.4710
# Iteration: 77; Percent complete: 1.9%; Average loss: 5.3244
# Iteration: 78; Percent complete: 1.9%; Average loss: 5.1554
# Iteration: 79; Percent complete: 2.0%; Average loss: 5.1226
# Iteration: 80; Percent complete: 2.0%; Average loss: 5.1136
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.7767
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.7767
# Iteration: 82; Percent complete: 2.1%; Average loss: 5.0737
# Iteration: 83; Percent complete: 2.1%; Average loss: 5.1920
# Iteration: 84; Percent complete: 2.1%; Average loss: 5.3074
# Iteration: 85; Percent complete: 2.1%; Average loss: 5.3445
# Iteration: 86; Percent complete: 2.1%; Average loss: 5.2756
# Iteration: 87; Percent complete: 2.2%; Average loss: 5.1925
# Iteration: 88; Percent complete: 2.2%; Average loss: 5.2920
# Iteration: 89; Percent complete: 2.2%; Average loss: 5.1687
# Iteration: 90; Percent complete: 2.2%; Average loss: 5.1910
# Iteration: 91; Percent complete: 2.3%; Average loss: 5.2230
# Iteration: 92; Percent complete: 2.3%; Average loss: 5.4189
# Iteration: 93; Percent complete: 2.3%; Average loss: 5.3248
# Iteration: 94; Percent complete: 2.4%; Average loss: 5.4114
# Iteration: 95; Percent complete: 2.4%; Average loss: 5.0827
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.9990
# Iteration: 97; Percent complete: 2.4%; Average loss: 5.1593
# Iteration: 98; Percent complete: 2.5%; Average loss: 5.2183
# Iteration: 99; Percent complete: 2.5%; Average loss: 5.3270
# Iteration: 100; Percent complete: 2.5%; Average loss: 5.2422
# Iteration: 101; Percent complete: 2.5%; Average loss: 5.1817
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.8889
# Iteration: 103; Percent complete: 2.6%; Average loss: 5.1763
# Iteration: 104; Percent complete: 2.6%; Average loss: 5.1863
# Iteration: 105; Percent complete: 2.6%; Average loss: 5.1269
# Iteration: 106; Percent complete: 2.6%; Average loss: 5.1463
# Iteration: 107; Percent complete: 2.7%; Average loss: 5.3671
# Iteration: 108; Percent complete: 2.7%; Average loss: 5.1019
# Iteration: 109; Percent complete: 2.7%; Average loss: 5.5688
# Iteration: 110; Percent complete: 2.8%; Average loss: 5.3698
# Iteration: 111; Percent complete: 2.8%; Average loss: 5.2070
# Iteration: 112; Percent complete: 2.8%; Average loss: 5.1267
# Iteration: 113; Percent complete: 2.8%; Average loss: 5.1231
# Iteration: 114; Percent complete: 2.9%; Average loss: 5.1162
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.9861
# Iteration: 116; Percent complete: 2.9%; Average loss: 5.3050
# Iteration: 117; Percent complete: 2.9%; Average loss: 5.1158
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.9194
# Iteration: 119; Percent complete: 3.0%; Average loss: 5.4620
# Iteration: 120; Percent complete: 3.0%; Average loss: 5.0824
# Iteration: 121; Percent complete: 3.0%; Average loss: 5.1223
# Iteration: 122; Percent complete: 3.0%; Average loss: 5.3061
# Iteration: 123; Percent complete: 3.1%; Average loss: 5.0311
# Iteration: 124; Percent complete: 3.1%; Average loss: 5.2097
# Iteration: 125; Percent complete: 3.1%; Average loss: 5.0183
# Iteration: 126; Percent complete: 3.1%; Average loss: 5.3609
# Iteration: 127; Percent complete: 3.2%; Average loss: 5.0364
# Iteration: 128; Percent complete: 3.2%; Average loss: 5.2763
# Iteration: 129; Percent complete: 3.2%; Average loss: 5.0746
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.9307
# Iteration: 131; Percent complete: 3.3%; Average loss: 5.3032
# Iteration: 132; Percent complete: 3.3%; Average loss: 5.3571
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.7463
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.7463
# Iteration: 134; Percent complete: 3.4%; Average loss: 5.1843
# Iteration: 135; Percent complete: 3.4%; Average loss: 5.4749
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.9038
# Iteration: 137; Percent complete: 3.4%; Average loss: 5.4708
# Iteration: 138; Percent complete: 3.5%; Average loss: 5.2960
# Iteration: 139; Percent complete: 3.5%; Average loss: 5.3381
# Iteration: 140; Percent complete: 3.5%; Average loss: 5.1415
# Iteration: 141; Percent complete: 3.5%; Average loss: 5.1871
# Iteration: 142; Percent complete: 3.5%; Average loss: 5.3021
# Iteration: 143; Percent complete: 3.6%; Average loss: 5.4041
# Iteration: 144; Percent complete: 3.6%; Average loss: 5.2715
# Iteration: 145; Percent complete: 3.6%; Average loss: 5.0590
# Iteration: 146; Percent complete: 3.6%; Average loss: 5.4198
# Iteration: 147; Percent complete: 3.7%; Average loss: 5.0385
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.8430
# Iteration: 149; Percent complete: 3.7%; Average loss: 5.1322
# Iteration: 150; Percent complete: 3.8%; Average loss: 5.2848
# Iteration: 151; Percent complete: 3.8%; Average loss: 5.0329
# Iteration: 152; Percent complete: 3.8%; Average loss: 5.1837
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.9774
# Iteration: 154; Percent complete: 3.9%; Average loss: 5.2186
# Iteration: 155; Percent complete: 3.9%; Average loss: 5.3415
# Iteration: 156; Percent complete: 3.9%; Average loss: 5.0041
# Iteration: 157; Percent complete: 3.9%; Average loss: 5.2334
# Iteration: 158; Percent complete: 4.0%; Average loss: 5.3347
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.9882
# Iteration: 160; Percent complete: 4.0%; Average loss: 5.0673
# Iteration: 161; Percent complete: 4.0%; Average loss: 5.4322
# Iteration: 162; Percent complete: 4.0%; Average loss: 5.2400
# Iteration: 163; Percent complete: 4.1%; Average loss: 5.1411
# Iteration: 164; Percent complete: 4.1%; Average loss: 5.2951
# Iteration: 165; Percent complete: 4.1%; Average loss: 5.2970
# Iteration: 166; Percent complete: 4.2%; Average loss: 5.2657
# Iteration: 167; Percent complete: 4.2%; Average loss: 5.2321
# Iteration: 168; Percent complete: 4.2%; Average loss: 5.3107
# Iteration: 169; Percent complete: 4.2%; Average loss: 5.1529
# Iteration: 170; Percent complete: 4.2%; Average loss: 5.3756
# Iteration: 171; Percent complete: 4.3%; Average loss: 5.4191
# Iteration: 172; Percent complete: 4.3%; Average loss: 5.4409
# Iteration: 173; Percent complete: 4.3%; Average loss: 5.4038
# Iteration: 174; Percent complete: 4.3%; Average loss: 5.3890
# Iteration: 175; Percent complete: 4.4%; Average loss: 5.2090
# Iteration: 176; Percent complete: 4.4%; Average loss: 5.1961
# Iteration: 177; Percent complete: 4.4%; Average loss: 5.2622
# Iteration: 178; Percent complete: 4.5%; Average loss: 5.2649
# Iteration: 179; Percent complete: 4.5%; Average loss: 5.2033
# Iteration: 180; Percent complete: 4.5%; Average loss: 5.0631
# Iteration: 181; Percent complete: 4.5%; Average loss: 5.3246
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.8700
# Iteration: 183; Percent complete: 4.6%; Average loss: 5.2298
# Iteration: 184; Percent complete: 4.6%; Average loss: 5.1328
# Iteration: 185; Percent complete: 4.6%; Average loss: 5.4051
# Iteration: 186; Percent complete: 4.7%; Average loss: 5.4462
# Iteration: 187; Percent complete: 4.7%; Average loss: 5.4794
# Iteration: 188; Percent complete: 4.7%; Average loss: 5.2476
# Iteration: 189; Percent complete: 4.7%; Average loss: 5.5129
# Iteration: 190; Percent complete: 4.8%; Average loss: 5.3338
# Iteration: 191; Percent complete: 4.8%; Average loss: 5.4361
# Iteration: 192; Percent complete: 4.8%; Average loss: 5.5388
# Iteration: 193; Percent complete: 4.8%; Average loss: 5.3241
# Iteration: 194; Percent complete: 4.9%; Average loss: 5.1407
# Iteration: 195; Percent complete: 4.9%; Average loss: 5.2971
# Iteration: 196; Percent complete: 4.9%; Average loss: 5.0533
# Iteration: 197; Percent complete: 4.9%; Average loss: 5.3573
# Iteration: 198; Percent complete: 5.0%; Average loss: 5.2637
# Iteration: 199; Percent complete: 5.0%; Average loss: 5.1550
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.9961
# Iteration: 201; Percent complete: 5.0%; Average loss: 5.4117
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.9100
# Iteration: 203; Percent complete: 5.1%; Average loss: 5.0582
# Iteration: 204; Percent complete: 5.1%; Average loss: 5.0453
# Iteration: 205; Percent complete: 5.1%; Average loss: 5.1099
# Iteration: 206; Percent complete: 5.1%; Average loss: 5.2606
# Iteration: 207; Percent complete: 5.2%; Average loss: 5.3083
# Iteration: 208; Percent complete: 5.2%; Average loss: 5.0237
# Iteration: 209; Percent complete: 5.2%; Average loss: 5.3415
# Iteration: 210; Percent complete: 5.2%; Average loss: 5.0490
# Iteration: 211; Percent complete: 5.3%; Average loss: 5.0548
# Iteration: 212; Percent complete: 5.3%; Average loss: 5.2443
# Iteration: 213; Percent complete: 5.3%; Average loss: 5.5917
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.9577
# Iteration: 215; Percent complete: 5.4%; Average loss: 5.2938
# Iteration: 216; Percent complete: 5.4%; Average loss: 5.4777
# Iteration: 217; Percent complete: 5.4%; Average loss: 5.0676
# Iteration: 218; Percent complete: 5.5%; Average loss: 5.1899
# Iteration: 219; Percent complete: 5.5%; Average loss: 5.2364
# Iteration: 220; Percent complete: 5.5%; Average loss: 5.1395
# Iteration: 221; Percent complete: 5.5%; Average loss: 5.1656
# Iteration: 222; Percent complete: 5.5%; Average loss: 5.2952
# Iteration: 223; Percent complete: 5.6%; Average loss: 5.3233
# Iteration: 224; Percent complete: 5.6%; Average loss: 5.3165
# Iteration: 225; Percent complete: 5.6%; Average loss: 5.2600
# Iteration: 226; Percent complete: 5.7%; Average loss: 5.2057
# Iteration: 227; Percent complete: 5.7%; Average loss: 5.1214
# Iteration: 228; Percent complete: 5.7%; Average loss: 5.0985
# Iteration: 229; Percent complete: 5.7%; Average loss: 5.3948
# Iteration: 230; Percent complete: 5.8%; Average loss: 5.3593
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.9801
# Iteration: 232; Percent complete: 5.8%; Average loss: 5.5084
# Iteration: 233; Percent complete: 5.8%; Average loss: 5.1471
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.9246
# Iteration: 235; Percent complete: 5.9%; Average loss: 5.3584
# Iteration: 236; Percent complete: 5.9%; Average loss: 5.1589
# Iteration: 237; Percent complete: 5.9%; Average loss: 5.2511
# Iteration: 238; Percent complete: 5.9%; Average loss: 5.3432
# Iteration: 239; Percent complete: 6.0%; Average loss: 5.0704
# Iteration: 240; Percent complete: 6.0%; Average loss: 5.3857
# Iteration: 241; Percent complete: 6.0%; Average loss: 5.2209
# Iteration: 242; Percent complete: 6.0%; Average loss: 5.3785
# Iteration: 243; Percent complete: 6.1%; Average loss: 5.1631
# Iteration: 244; Percent complete: 6.1%; Average loss: 5.2597
# Iteration: 245; Percent complete: 6.1%; Average loss: 5.1466
# Iteration: 246; Percent complete: 6.2%; Average loss: 5.4186
# Iteration: 247; Percent complete: 6.2%; Average loss: 5.2165
# Iteration: 248; Percent complete: 6.2%; Average loss: 5.2902
# Iteration: 249; Percent complete: 6.2%; Average loss: 5.1445
# Iteration: 250; Percent complete: 6.2%; Average loss: 5.1053
# Iteration: 251; Percent complete: 6.3%; Average loss: 4.9002
# Iteration: 252; Percent complete: 6.3%; Average loss: 5.1428
# Iteration: 253; Percent complete: 6.3%; Average loss: 5.0715
# Iteration: 254; Percent complete: 6.3%; Average loss: 5.2185
# Iteration: 255; Percent complete: 6.4%; Average loss: 5.4067
# Iteration: 256; Percent complete: 6.4%; Average loss: 5.2340
# Iteration: 257; Percent complete: 6.4%; Average loss: 5.5938
# Iteration: 258; Percent complete: 6.5%; Average loss: 5.0156
# Iteration: 259; Percent complete: 6.5%; Average loss: 5.2541
# Iteration: 260; Percent complete: 6.5%; Average loss: 5.1322
# Iteration: 261; Percent complete: 6.5%; Average loss: 5.5779
# Iteration: 262; Percent complete: 6.6%; Average loss: 5.1431
# Iteration: 263; Percent complete: 6.6%; Average loss: 5.1295
# Iteration: 264; Percent complete: 6.6%; Average loss: 5.1628
# Iteration: 265; Percent complete: 6.6%; Average loss: 5.3676
# Iteration: 266; Percent complete: 6.7%; Average loss: 5.2026
# Iteration: 267; Percent complete: 6.7%; Average loss: 5.3856
# Iteration: 268; Percent complete: 6.7%; Average loss: 5.0171
# Iteration: 269; Percent complete: 6.7%; Average loss: 5.1673
# Iteration: 270; Percent complete: 6.8%; Average loss: 5.1483
# Iteration: 271; Percent complete: 6.8%; Average loss: 5.5029
# Iteration: 272; Percent complete: 6.8%; Average loss: 5.0295
# Iteration: 273; Percent complete: 6.8%; Average loss: 5.2082
# Iteration: 274; Percent complete: 6.9%; Average loss: 5.1874
# Iteration: 275; Percent complete: 6.9%; Average loss: 5.7813
# Iteration: 276; Percent complete: 6.9%; Average loss: 5.3061
# Iteration: 277; Percent complete: 6.9%; Average loss: 5.5362
# Iteration: 278; Percent complete: 7.0%; Average loss: 5.1507
# Iteration: 279; Percent complete: 7.0%; Average loss: 5.2115
# Iteration: 280; Percent complete: 7.0%; Average loss: 5.3625
# Iteration: 281; Percent complete: 7.0%; Average loss: 5.1792
# Iteration: 282; Percent complete: 7.0%; Average loss: 5.2646
# Iteration: 283; Percent complete: 7.1%; Average loss: 5.4183
# Iteration: 284; Percent complete: 7.1%; Average loss: 5.2352
# Iteration: 285; Percent complete: 7.1%; Average loss: 5.3013
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.9973
# Iteration: 287; Percent complete: 7.2%; Average loss: 5.2315
# Iteration: 288; Percent complete: 7.2%; Average loss: 5.3380
# Iteration: 289; Percent complete: 7.2%; Average loss: 5.2870
# Iteration: 290; Percent complete: 7.2%; Average loss: 5.1987
# Iteration: 291; Percent complete: 7.3%; Average loss: 5.3375
# Iteration: 292; Percent complete: 7.3%; Average loss: 5.3356
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.9560
# Iteration: 294; Percent complete: 7.3%; Average loss: 5.1380
# Iteration: 295; Percent complete: 7.4%; Average loss: 5.2658
# Iteration: 296; Percent complete: 7.4%; Average loss: 5.3230
# Iteration: 297; Percent complete: 7.4%; Average loss: 5.4864
# Iteration: 298; Percent complete: 7.4%; Average loss: 5.2372
# Iteration: 299; Percent complete: 7.5%; Average loss: 5.1957
# Iteration: 300; Percent complete: 7.5%; Average loss: 5.3484
# Iteration: 301; Percent complete: 7.5%; Average loss: 5.2235
# Iteration: 302; Percent complete: 7.5%; Average loss: 5.1002
# Iteration: 303; Percent complete: 7.6%; Average loss: 5.0511
# Iteration: 304; Percent complete: 7.6%; Average loss: 5.1570
# Iteration: 305; Percent complete: 7.6%; Average loss: 5.2999
# Iteration: 306; Percent complete: 7.6%; Average loss: 5.3257
# Iteration: 307; Percent complete: 7.7%; Average loss: 5.3930
# Iteration: 308; Percent complete: 7.7%; Average loss: 5.3182
# Iteration: 309; Percent complete: 7.7%; Average loss: 5.2172
# Iteration: 310; Percent complete: 7.8%; Average loss: 5.2387
# Iteration: 311; Percent complete: 7.8%; Average loss: 5.4057
# Iteration: 312; Percent complete: 7.8%; Average loss: 5.1282
# Iteration: 313; Percent complete: 7.8%; Average loss: 5.1857
# Iteration: 314; Percent complete: 7.8%; Average loss: 5.1442
# Iteration: 315; Percent complete: 7.9%; Average loss: 5.3280
# Iteration: 316; Percent complete: 7.9%; Average loss: 5.2221
# Iteration: 317; Percent complete: 7.9%; Average loss: 5.4497
# Iteration: 318; Percent complete: 8.0%; Average loss: 5.2411
# Iteration: 319; Percent complete: 8.0%; Average loss: 5.0816
# Iteration: 320; Percent complete: 8.0%; Average loss: 5.3077
# Iteration: 321; Percent complete: 8.0%; Average loss: 5.3032
# Iteration: 322; Percent complete: 8.1%; Average loss: 5.3575
# Iteration: 323; Percent complete: 8.1%; Average loss: 5.1347
# Iteration: 324; Percent complete: 8.1%; Average loss: 5.3319
# Iteration: 325; Percent complete: 8.1%; Average loss: 5.1552
# Iteration: 326; Percent complete: 8.2%; Average loss: 4.9936
# Iteration: 327; Percent complete: 8.2%; Average loss: 5.4391
# Iteration: 328; Percent complete: 8.2%; Average loss: 5.1908
# Iteration: 329; Percent complete: 8.2%; Average loss: 5.5785
# Iteration: 330; Percent complete: 8.2%; Average loss: 5.4236
# Iteration: 331; Percent complete: 8.3%; Average loss: 5.2279
# Iteration: 332; Percent complete: 8.3%; Average loss: 5.3791
# Iteration: 333; Percent complete: 8.3%; Average loss: 5.1800
# Iteration: 334; Percent complete: 8.3%; Average loss: 5.2220
# Iteration: 335; Percent complete: 8.4%; Average loss: 5.4610
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.8306
# Iteration: 337; Percent complete: 8.4%; Average loss: 5.1642
# Iteration: 338; Percent complete: 8.5%; Average loss: 5.0417
# Iteration: 339; Percent complete: 8.5%; Average loss: 5.1702
# Iteration: 340; Percent complete: 8.5%; Average loss: 4.9343
# Iteration: 341; Percent complete: 8.5%; Average loss: 5.3754
# Iteration: 342; Percent complete: 8.6%; Average loss: 5.3730
# Iteration: 343; Percent complete: 8.6%; Average loss: 5.1234
# Iteration: 344; Percent complete: 8.6%; Average loss: 5.1256
# Iteration: 345; Percent complete: 8.6%; Average loss: 5.3485
# Iteration: 346; Percent complete: 8.6%; Average loss: 4.8851
# Iteration: 347; Percent complete: 8.7%; Average loss: 5.1664
# Iteration: 348; Percent complete: 8.7%; Average loss: 5.2031
# Iteration: 349; Percent complete: 8.7%; Average loss: 4.9685
# Iteration: 350; Percent complete: 8.8%; Average loss: 5.4104
# Iteration: 351; Percent complete: 8.8%; Average loss: 5.2394
# Iteration: 352; Percent complete: 8.8%; Average loss: 5.3252
# Iteration: 353; Percent complete: 8.8%; Average loss: 4.7837
# Iteration: 354; Percent complete: 8.8%; Average loss: 5.3761
# Iteration: 355; Percent complete: 8.9%; Average loss: 5.0666
# Iteration: 356; Percent complete: 8.9%; Average loss: 5.7081
# Iteration: 357; Percent complete: 8.9%; Average loss: 5.2495
# Iteration: 358; Percent complete: 8.9%; Average loss: 5.1718
# Iteration: 359; Percent complete: 9.0%; Average loss: 5.2075
# Iteration: 360; Percent complete: 9.0%; Average loss: 5.1014
# Iteration: 361; Percent complete: 9.0%; Average loss: 5.3360
# Iteration: 362; Percent complete: 9.0%; Average loss: 5.0253
# Iteration: 363; Percent complete: 9.1%; Average loss: 5.1853
# Iteration: 364; Percent complete: 9.1%; Average loss: 5.3334
# Iteration: 365; Percent complete: 9.1%; Average loss: 5.2723
# Iteration: 366; Percent complete: 9.2%; Average loss: 5.3573
# Iteration: 367; Percent complete: 9.2%; Average loss: 4.8593
# Iteration: 368; Percent complete: 9.2%; Average loss: 5.0996
# Iteration: 369; Percent complete: 9.2%; Average loss: 5.0774
# Iteration: 370; Percent complete: 9.2%; Average loss: 4.9711
# Iteration: 371; Percent complete: 9.3%; Average loss: 5.2037
# Iteration: 372; Percent complete: 9.3%; Average loss: 5.4267
# Iteration: 373; Percent complete: 9.3%; Average loss: 5.1285
# Iteration: 374; Percent complete: 9.3%; Average loss: 5.1336
# Iteration: 375; Percent complete: 9.4%; Average loss: 5.0645
# Iteration: 376; Percent complete: 9.4%; Average loss: 5.0561
# Iteration: 377; Percent complete: 9.4%; Average loss: 5.3189
# Iteration: 378; Percent complete: 9.4%; Average loss: 5.4536
# Iteration: 379; Percent complete: 9.5%; Average loss: 5.3575
# Iteration: 380; Percent complete: 9.5%; Average loss: 5.4751
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.9116
# Iteration: 382; Percent complete: 9.6%; Average loss: 5.2721
# Iteration: 383; Percent complete: 9.6%; Average loss: 5.1490
# Iteration: 384; Percent complete: 9.6%; Average loss: 5.2504
# Iteration: 385; Percent complete: 9.6%; Average loss: 5.2920
# Iteration: 386; Percent complete: 9.7%; Average loss: 5.3060
# Iteration: 387; Percent complete: 9.7%; Average loss: 5.3188
# Iteration: 388; Percent complete: 9.7%; Average loss: 5.1341
# Iteration: 389; Percent complete: 9.7%; Average loss: 5.1486
# Iteration: 390; Percent complete: 9.8%; Average loss: 4.9579
# Iteration: 391; Percent complete: 9.8%; Average loss: 5.2407
# Iteration: 392; Percent complete: 9.8%; Average loss: 5.0809
# Iteration: 393; Percent complete: 9.8%; Average loss: 5.3861
# Iteration: 394; Percent complete: 9.8%; Average loss: 5.2710
# Iteration: 395; Percent complete: 9.9%; Average loss: 4.9893
# Iteration: 396; Percent complete: 9.9%; Average loss: 5.0522
# Iteration: 397; Percent complete: 9.9%; Average loss: 5.1232
# Iteration: 398; Percent complete: 10.0%; Average loss: 5.2414
# Iteration: 399; Percent complete: 10.0%; Average loss: 5.1443
# Iteration: 400; Percent complete: 10.0%; Average loss: 5.3122
# Iteration: 401; Percent complete: 10.0%; Average loss: 5.1399
# Iteration: 402; Percent complete: 10.1%; Average loss: 5.5770
# Iteration: 403; Percent complete: 10.1%; Average loss: 5.1925
# Iteration: 404; Percent complete: 10.1%; Average loss: 5.1345
# Iteration: 405; Percent complete: 10.1%; Average loss: 5.0529
# Iteration: 406; Percent complete: 10.2%; Average loss: 5.4060
# Iteration: 407; Percent complete: 10.2%; Average loss: 5.3619
# Iteration: 408; Percent complete: 10.2%; Average loss: 4.8997
# Iteration: 409; Percent complete: 10.2%; Average loss: 5.4452
# Iteration: 410; Percent complete: 10.2%; Average loss: 5.2065
# Iteration: 411; Percent complete: 10.3%; Average loss: 5.4861
# Iteration: 412; Percent complete: 10.3%; Average loss: 5.4524
# Iteration: 413; Percent complete: 10.3%; Average loss: 5.2199
# Iteration: 414; Percent complete: 10.3%; Average loss: 5.0969
# Iteration: 415; Percent complete: 10.4%; Average loss: 5.1716
# Iteration: 416; Percent complete: 10.4%; Average loss: 5.0904
# Iteration: 417; Percent complete: 10.4%; Average loss: 5.2989
# Iteration: 418; Percent complete: 10.4%; Average loss: 5.1383
# Iteration: 419; Percent complete: 10.5%; Average loss: 5.3085
# Iteration: 420; Percent complete: 10.5%; Average loss: 5.1935
# Iteration: 421; Percent complete: 10.5%; Average loss: 5.0854
# Iteration: 422; Percent complete: 10.5%; Average loss: 5.1426
# Iteration: 423; Percent complete: 10.6%; Average loss: 5.0977
# Iteration: 424; Percent complete: 10.6%; Average loss: 5.1513
# Iteration: 425; Percent complete: 10.6%; Average loss: 5.1953
# Iteration: 426; Percent complete: 10.7%; Average loss: 5.2805
# Iteration: 427; Percent complete: 10.7%; Average loss: 5.2429
# Iteration: 428; Percent complete: 10.7%; Average loss: 5.3484
# Iteration: 429; Percent complete: 10.7%; Average loss: 5.3815
# Iteration: 430; Percent complete: 10.8%; Average loss: 5.6010
# Iteration: 431; Percent complete: 10.8%; Average loss: 5.3289
# Iteration: 432; Percent complete: 10.8%; Average loss: 5.4031
# Iteration: 433; Percent complete: 10.8%; Average loss: 5.3543
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.9632
# Iteration: 435; Percent complete: 10.9%; Average loss: 5.3617
# Iteration: 436; Percent complete: 10.9%; Average loss: 5.3524
# Iteration: 437; Percent complete: 10.9%; Average loss: 5.2225
# Iteration: 438; Percent complete: 10.9%; Average loss: 5.6126
# Iteration: 439; Percent complete: 11.0%; Average loss: 4.9656
# Iteration: 440; Percent complete: 11.0%; Average loss: 5.0684
# Iteration: 441; Percent complete: 11.0%; Average loss: 5.6524
# Iteration: 442; Percent complete: 11.1%; Average loss: 5.4381
# Iteration: 443; Percent complete: 11.1%; Average loss: 4.8094
# Iteration: 444; Percent complete: 11.1%; Average loss: 5.4274
# Iteration: 445; Percent complete: 11.1%; Average loss: 5.0962
# Iteration: 446; Percent complete: 11.2%; Average loss: 5.5036
# Iteration: 447; Percent complete: 11.2%; Average loss: 5.1432
# Iteration: 448; Percent complete: 11.2%; Average loss: 5.4942
# Iteration: 449; Percent complete: 11.2%; Average loss: 5.0963
# Iteration: 450; Percent complete: 11.2%; Average loss: 5.0148
# Iteration: 451; Percent complete: 11.3%; Average loss: 5.2125
# Iteration: 452; Percent complete: 11.3%; Average loss: 5.1294
# Iteration: 453; Percent complete: 11.3%; Average loss: 5.0672
# Iteration: 454; Percent complete: 11.3%; Average loss: 5.1084
# Iteration: 455; Percent complete: 11.4%; Average loss: 5.0827
# Iteration: 456; Percent complete: 11.4%; Average loss: 5.2322
# Iteration: 457; Percent complete: 11.4%; Average loss: 5.3421
# Iteration: 458; Percent complete: 11.5%; Average loss: 5.0581
# Iteration: 459; Percent complete: 11.5%; Average loss: 5.2693
# Iteration: 460; Percent complete: 11.5%; Average loss: 5.2216
# Iteration: 461; Percent complete: 11.5%; Average loss: 5.3054
# Iteration: 462; Percent complete: 11.6%; Average loss: 5.2301
# Iteration: 463; Percent complete: 11.6%; Average loss: 5.1946
# Iteration: 464; Percent complete: 11.6%; Average loss: 5.2652
# Iteration: 465; Percent complete: 11.6%; Average loss: 4.9802
# Iteration: 466; Percent complete: 11.7%; Average loss: 4.9626
# Iteration: 467; Percent complete: 11.7%; Average loss: 4.9525
# Iteration: 468; Percent complete: 11.7%; Average loss: 5.2253
# Iteration: 469; Percent complete: 11.7%; Average loss: 5.1068
# Iteration: 470; Percent complete: 11.8%; Average loss: 5.3207
# Iteration: 471; Percent complete: 11.8%; Average loss: 5.1621
# Iteration: 472; Percent complete: 11.8%; Average loss: 5.0574
# Iteration: 473; Percent complete: 11.8%; Average loss: 5.0274
# Iteration: 474; Percent complete: 11.8%; Average loss: 4.9930
# Iteration: 475; Percent complete: 11.9%; Average loss: 5.3893
# Iteration: 476; Percent complete: 11.9%; Average loss: 5.0824
# Iteration: 477; Percent complete: 11.9%; Average loss: 5.3097
# Iteration: 478; Percent complete: 11.9%; Average loss: 5.1194
# Iteration: 479; Percent complete: 12.0%; Average loss: 5.2346
# Iteration: 480; Percent complete: 12.0%; Average loss: 5.3474
# Iteration: 481; Percent complete: 12.0%; Average loss: 5.1337
# Iteration: 482; Percent complete: 12.0%; Average loss: 5.4127
# Iteration: 483; Percent complete: 12.1%; Average loss: 5.2035
# Iteration: 484; Percent complete: 12.1%; Average loss: 5.2903
# Iteration: 485; Percent complete: 12.1%; Average loss: 5.2776
# Iteration: 486; Percent complete: 12.2%; Average loss: 5.3399
# Iteration: 487; Percent complete: 12.2%; Average loss: 5.2175
# Iteration: 488; Percent complete: 12.2%; Average loss: 5.3890
# Iteration: 489; Percent complete: 12.2%; Average loss: 5.2579
# Iteration: 490; Percent complete: 12.2%; Average loss: 5.2007
# Iteration: 491; Percent complete: 12.3%; Average loss: 5.4403
# Iteration: 492; Percent complete: 12.3%; Average loss: 5.1521
# Iteration: 493; Percent complete: 12.3%; Average loss: 5.3501
# Iteration: 494; Percent complete: 12.3%; Average loss: 5.0238
# Iteration: 495; Percent complete: 12.4%; Average loss: 5.0998
# Iteration: 496; Percent complete: 12.4%; Average loss: 5.2080
# Iteration: 497; Percent complete: 12.4%; Average loss: 4.9435
# Iteration: 498; Percent complete: 12.4%; Average loss: 5.1216
# Iteration: 499; Percent complete: 12.5%; Average loss: 5.2971
# Iteration: 500; Percent complete: 12.5%; Average loss: 5.5335
# Iteration: 501; Percent complete: 12.5%; Average loss: 4.9740
# Iteration: 502; Percent complete: 12.6%; Average loss: 5.2135
# Iteration: 503; Percent complete: 12.6%; Average loss: 5.1722
# Iteration: 504; Percent complete: 12.6%; Average loss: 5.3996
# Iteration: 505; Percent complete: 12.6%; Average loss: 5.0866
# Iteration: 506; Percent complete: 12.7%; Average loss: 5.3509
# Iteration: 507; Percent complete: 12.7%; Average loss: 5.4040
# Iteration: 508; Percent complete: 12.7%; Average loss: 4.8481
# Iteration: 509; Percent complete: 12.7%; Average loss: 5.4334
# Iteration: 510; Percent complete: 12.8%; Average loss: 5.1454
# Iteration: 511; Percent complete: 12.8%; Average loss: 5.1100
# Iteration: 512; Percent complete: 12.8%; Average loss: 5.1150
# Iteration: 513; Percent complete: 12.8%; Average loss: 5.3387
# Iteration: 514; Percent complete: 12.8%; Average loss: 5.2110
# Iteration: 515; Percent complete: 12.9%; Average loss: 4.8955
# Iteration: 516; Percent complete: 12.9%; Average loss: 5.2131
# Iteration: 517; Percent complete: 12.9%; Average loss: 5.2037
# Iteration: 518; Percent complete: 13.0%; Average loss: 4.8934
# Iteration: 519; Percent complete: 13.0%; Average loss: 5.1123
# Iteration: 520; Percent complete: 13.0%; Average loss: 5.3084
# Iteration: 521; Percent complete: 13.0%; Average loss: 5.1870
# Iteration: 522; Percent complete: 13.1%; Average loss: 5.2822
# Iteration: 523; Percent complete: 13.1%; Average loss: 5.4813
# Iteration: 524; Percent complete: 13.1%; Average loss: 5.2420
# Iteration: 525; Percent complete: 13.1%; Average loss: 5.4759
# Iteration: 526; Percent complete: 13.2%; Average loss: 5.3577
# Iteration: 527; Percent complete: 13.2%; Average loss: 5.2510
# Iteration: 528; Percent complete: 13.2%; Average loss: 5.4006
# Iteration: 529; Percent complete: 13.2%; Average loss: 5.3486
# Iteration: 530; Percent complete: 13.2%; Average loss: 5.4765
# Iteration: 531; Percent complete: 13.3%; Average loss: 5.1252
# Iteration: 532; Percent complete: 13.3%; Average loss: 5.5386
# Iteration: 533; Percent complete: 13.3%; Average loss: 5.2994
# Iteration: 534; Percent complete: 13.4%; Average loss: 5.1189
# Iteration: 535; Percent complete: 13.4%; Average loss: 4.9520
# Iteration: 536; Percent complete: 13.4%; Average loss: 5.3047
# Iteration: 537; Percent complete: 13.4%; Average loss: 5.1741
# Iteration: 538; Percent complete: 13.5%; Average loss: 5.2031
# Iteration: 539; Percent complete: 13.5%; Average loss: 5.1363
# Iteration: 540; Percent complete: 13.5%; Average loss: 5.4224
# Iteration: 541; Percent complete: 13.5%; Average loss: 5.4674
# Iteration: 542; Percent complete: 13.6%; Average loss: 5.2577
# Iteration: 543; Percent complete: 13.6%; Average loss: 5.1413
# Iteration: 544; Percent complete: 13.6%; Average loss: 5.1273
# Iteration: 545; Percent complete: 13.6%; Average loss: 5.4377
# Iteration: 546; Percent complete: 13.7%; Average loss: 5.4533
# Iteration: 547; Percent complete: 13.7%; Average loss: 5.2635
# Iteration: 548; Percent complete: 13.7%; Average loss: 5.2360
# Iteration: 549; Percent complete: 13.7%; Average loss: 5.3352
# Iteration: 550; Percent complete: 13.8%; Average loss: 5.3081
# Iteration: 551; Percent complete: 13.8%; Average loss: 5.2720
# Iteration: 552; Percent complete: 13.8%; Average loss: 5.3614
# Iteration: 553; Percent complete: 13.8%; Average loss: 5.2668
# Iteration: 554; Percent complete: 13.9%; Average loss: 5.0328
# Iteration: 555; Percent complete: 13.9%; Average loss: 5.3140
# Iteration: 556; Percent complete: 13.9%; Average loss: 5.2830
# Iteration: 557; Percent complete: 13.9%; Average loss: 5.3561
# Iteration: 558; Percent complete: 14.0%; Average loss: 5.2109
# Iteration: 559; Percent complete: 14.0%; Average loss: 5.2459
# Iteration: 560; Percent complete: 14.0%; Average loss: 5.0895
# Iteration: 561; Percent complete: 14.0%; Average loss: 5.1739
# Iteration: 562; Percent complete: 14.1%; Average loss: 5.3159
# Iteration: 563; Percent complete: 14.1%; Average loss: 5.2014
# Iteration: 564; Percent complete: 14.1%; Average loss: 4.9796
# Iteration: 565; Percent complete: 14.1%; Average loss: 5.1691
# Iteration: 566; Percent complete: 14.1%; Average loss: 5.1356
# Iteration: 567; Percent complete: 14.2%; Average loss: 5.2252
# Iteration: 568; Percent complete: 14.2%; Average loss: 5.2198
# Iteration: 569; Percent complete: 14.2%; Average loss: 4.9940
# Iteration: 570; Percent complete: 14.2%; Average loss: 5.2914
# Iteration: 571; Percent complete: 14.3%; Average loss: 5.1465
# Iteration: 572; Percent complete: 14.3%; Average loss: 5.2071
# Iteration: 573; Percent complete: 14.3%; Average loss: 5.3062
# Iteration: 574; Percent complete: 14.3%; Average loss: 5.4273
# Iteration: 575; Percent complete: 14.4%; Average loss: 5.4572
# Iteration: 576; Percent complete: 14.4%; Average loss: 5.3352
# Iteration: 577; Percent complete: 14.4%; Average loss: 5.1563
# Iteration: 578; Percent complete: 14.4%; Average loss: 5.3354
# Iteration: 579; Percent complete: 14.5%; Average loss: 5.1555
# Iteration: 580; Percent complete: 14.5%; Average loss: 5.4643
# Iteration: 581; Percent complete: 14.5%; Average loss: 5.0120
# Iteration: 582; Percent complete: 14.5%; Average loss: 5.3154
# Iteration: 583; Percent complete: 14.6%; Average loss: 5.1821
# Iteration: 584; Percent complete: 14.6%; Average loss: 5.0929
# Iteration: 585; Percent complete: 14.6%; Average loss: 5.5175
# Iteration: 586; Percent complete: 14.6%; Average loss: 5.1532
# Iteration: 587; Percent complete: 14.7%; Average loss: 5.2431
# Iteration: 588; Percent complete: 14.7%; Average loss: 5.2834
# Iteration: 589; Percent complete: 14.7%; Average loss: 5.2549
# Iteration: 590; Percent complete: 14.8%; Average loss: 5.1912
# Iteration: 591; Percent complete: 14.8%; Average loss: 5.1507
# Iteration: 592; Percent complete: 14.8%; Average loss: 5.5459
# Iteration: 593; Percent complete: 14.8%; Average loss: 5.2171
# Iteration: 594; Percent complete: 14.8%; Average loss: 5.4072
# Iteration: 595; Percent complete: 14.9%; Average loss: 5.2638
# Iteration: 596; Percent complete: 14.9%; Average loss: 4.9903
# Iteration: 597; Percent complete: 14.9%; Average loss: 5.2955
# Iteration: 598; Percent complete: 14.9%; Average loss: 5.0424
# Iteration: 599; Percent complete: 15.0%; Average loss: 5.3283
# Iteration: 600; Percent complete: 15.0%; Average loss: 5.3987
# Iteration: 601; Percent complete: 15.0%; Average loss: 5.2144
# Iteration: 602; Percent complete: 15.0%; Average loss: 4.7146
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.7146
# Iteration: 603; Percent complete: 15.1%; Average loss: 5.2731
# Iteration: 604; Percent complete: 15.1%; Average loss: 5.2152
# Iteration: 605; Percent complete: 15.1%; Average loss: 5.1029
# Iteration: 606; Percent complete: 15.2%; Average loss: 5.0547
# Iteration: 607; Percent complete: 15.2%; Average loss: 4.8431
# Iteration: 608; Percent complete: 15.2%; Average loss: 5.2725
# Iteration: 609; Percent complete: 15.2%; Average loss: 5.3844
# Iteration: 610; Percent complete: 15.2%; Average loss: 4.8881
# Iteration: 611; Percent complete: 15.3%; Average loss: 5.0305
# Iteration: 612; Percent complete: 15.3%; Average loss: 5.1014
# Iteration: 613; Percent complete: 15.3%; Average loss: 5.2523
# Iteration: 614; Percent complete: 15.3%; Average loss: 5.3877
# Iteration: 615; Percent complete: 15.4%; Average loss: 5.1403
# Iteration: 616; Percent complete: 15.4%; Average loss: 5.3851
# Iteration: 617; Percent complete: 15.4%; Average loss: 5.3195
# Iteration: 618; Percent complete: 15.4%; Average loss: 5.2729
# Iteration: 619; Percent complete: 15.5%; Average loss: 5.4278
# Iteration: 620; Percent complete: 15.5%; Average loss: 5.2956
# Iteration: 621; Percent complete: 15.5%; Average loss: 5.0565
# Iteration: 622; Percent complete: 15.6%; Average loss: 5.3838
# Iteration: 623; Percent complete: 15.6%; Average loss: 5.0938
# Iteration: 624; Percent complete: 15.6%; Average loss: 5.1318
# Iteration: 625; Percent complete: 15.6%; Average loss: 5.1709
# Iteration: 626; Percent complete: 15.7%; Average loss: 5.1505
# Iteration: 627; Percent complete: 15.7%; Average loss: 5.1319
# Iteration: 628; Percent complete: 15.7%; Average loss: 5.2759
# Iteration: 629; Percent complete: 15.7%; Average loss: 4.9687
# Iteration: 630; Percent complete: 15.8%; Average loss: 5.1017
# Iteration: 631; Percent complete: 15.8%; Average loss: 5.2973
# Iteration: 632; Percent complete: 15.8%; Average loss: 5.0528
# Iteration: 633; Percent complete: 15.8%; Average loss: 4.9968
# Iteration: 634; Percent complete: 15.8%; Average loss: 5.1264
# Iteration: 635; Percent complete: 15.9%; Average loss: 5.0232
# Iteration: 636; Percent complete: 15.9%; Average loss: 4.8748
# Iteration: 637; Percent complete: 15.9%; Average loss: 5.2253
# Iteration: 638; Percent complete: 16.0%; Average loss: 5.1844
# Iteration: 639; Percent complete: 16.0%; Average loss: 5.1219
# Iteration: 640; Percent complete: 16.0%; Average loss: 5.2460
# Iteration: 641; Percent complete: 16.0%; Average loss: 5.0690
# Iteration: 642; Percent complete: 16.1%; Average loss: 5.1969
# Iteration: 643; Percent complete: 16.1%; Average loss: 5.2563
# Iteration: 644; Percent complete: 16.1%; Average loss: 5.4061
# Iteration: 645; Percent complete: 16.1%; Average loss: 5.5034
# Iteration: 646; Percent complete: 16.2%; Average loss: 5.2577
# Iteration: 647; Percent complete: 16.2%; Average loss: 4.6579
# Best model saved at data/save/cb_model/movie-corpus/2-2_500/best_model_lr0.00025_clip0_tf0_optsgd_dlr5.pth with loss 4.6579
# Iteration: 648; Percent complete: 16.2%; Average loss: 5.2569
# Iteration: 649; Percent complete: 16.2%; Average loss: 5.2432
# Iteration: 650; Percent complete: 16.2%; Average loss: 5.1058
# Iteration: 651; Percent complete: 16.3%; Average loss: 5.3916
# Iteration: 652; Percent complete: 16.3%; Average loss: 5.1827
# Iteration: 653; Percent complete: 16.3%; Average loss: 5.0614
# Iteration: 654; Percent complete: 16.4%; Average loss: 5.3208
# Iteration: 655; Percent complete: 16.4%; Average loss: 5.1707
# Iteration: 656; Percent complete: 16.4%; Average loss: 5.0588
# Iteration: 657; Percent complete: 16.4%; Average loss: 5.0409
# Iteration: 658; Percent complete: 16.4%; Average loss: 5.5819
# Iteration: 659; Percent complete: 16.5%; Average loss: 5.1973
# Iteration: 660; Percent complete: 16.5%; Average loss: 5.3485
# Iteration: 661; Percent complete: 16.5%; Average loss: 4.8604
# Iteration: 662; Percent complete: 16.6%; Average loss: 5.2737
# Iteration: 663; Percent complete: 16.6%; Average loss: 5.2527
# Iteration: 664; Percent complete: 16.6%; Average loss: 5.2657
# Iteration: 665; Percent complete: 16.6%; Average loss: 5.3524
# Iteration: 666; Percent complete: 16.7%; Average loss: 5.0004
# Iteration: 667; Percent complete: 16.7%; Average loss: 5.3752
# Iteration: 668; Percent complete: 16.7%; Average loss: 5.0648
# Iteration: 669; Percent complete: 16.7%; Average loss: 5.1085
# Iteration: 670; Percent complete: 16.8%; Average loss: 5.3252
# Iteration: 671; Percent complete: 16.8%; Average loss: 5.1861
# Iteration: 672; Percent complete: 16.8%; Average loss: 5.1216
# Iteration: 673; Percent complete: 16.8%; Average loss: 5.1879
# Iteration: 674; Percent complete: 16.9%; Average loss: 5.2409
# Iteration: 675; Percent complete: 16.9%; Average loss: 4.9683
# Iteration: 676; Percent complete: 16.9%; Average loss: 5.1839
# Iteration: 677; Percent complete: 16.9%; Average loss: 5.1756
# Iteration: 678; Percent complete: 17.0%; Average loss: 5.2630
# Iteration: 679; Percent complete: 17.0%; Average loss: 5.2482
# Iteration: 680; Percent complete: 17.0%; Average loss: 5.1698
# Iteration: 681; Percent complete: 17.0%; Average loss: 5.1597
# Iteration: 682; Percent complete: 17.1%; Average loss: 4.9161
# Iteration: 683; Percent complete: 17.1%; Average loss: 5.3420
# Iteration: 684; Percent complete: 17.1%; Average loss: 5.3475
# Iteration: 685; Percent complete: 17.1%; Average loss: 5.0787
# Iteration: 686; Percent complete: 17.2%; Average loss: 5.0616
# Iteration: 687; Percent complete: 17.2%; Average loss: 5.0905
# Iteration: 688; Percent complete: 17.2%; Average loss: 5.2059
# Iteration: 689; Percent complete: 17.2%; Average loss: 5.4348
# Iteration: 690; Percent complete: 17.2%; Average loss: 5.1807
# Iteration: 691; Percent complete: 17.3%; Average loss: 5.3226
# Iteration: 692; Percent complete: 17.3%; Average loss: 5.1751
# Iteration: 693; Percent complete: 17.3%; Average loss: 5.0674
# Iteration: 694; Percent complete: 17.3%; Average loss: 5.2719
# Iteration: 695; Percent complete: 17.4%; Average loss: 5.2436
# Iteration: 696; Percent complete: 17.4%; Average loss: 5.3473
# Iteration: 697; Percent complete: 17.4%; Average loss: 5.2133
# Iteration: 698; Percent complete: 17.4%; Average loss: 5.4157
# Iteration: 699; Percent complete: 17.5%; Average loss: 5.1904
# Iteration: 700; Percent complete: 17.5%; Average loss: 5.1911
# Iteration: 701; Percent complete: 17.5%; Average loss: 5.2148
# Iteration: 702; Percent complete: 17.5%; Average loss: 5.1548
# Iteration: 703; Percent complete: 17.6%; Average loss: 5.1950
# Iteration: 704; Percent complete: 17.6%; Average loss: 5.5187
# Iteration: 705; Percent complete: 17.6%; Average loss: 5.4341
# Iteration: 706; Percent complete: 17.6%; Average loss: 5.5030
# Iteration: 707; Percent complete: 17.7%; Average loss: 5.2224
# Iteration: 708; Percent complete: 17.7%; Average loss: 5.2929
# Iteration: 709; Percent complete: 17.7%; Average loss: 5.2793
# Iteration: 710; Percent complete: 17.8%; Average loss: 5.2987
# Iteration: 711; Percent complete: 17.8%; Average loss: 5.2370
# Iteration: 712; Percent complete: 17.8%; Average loss: 5.3559
# Iteration: 713; Percent complete: 17.8%; Average loss: 5.1114
# Iteration: 714; Percent complete: 17.8%; Average loss: 4.9884
# Iteration: 715; Percent complete: 17.9%; Average loss: 5.2233
# Iteration: 716; Percent complete: 17.9%; Average loss: 5.2053
# Iteration: 717; Percent complete: 17.9%; Average loss: 5.1213
# Iteration: 718; Percent complete: 17.9%; Average loss: 5.5369
# Iteration: 719; Percent complete: 18.0%; Average loss: 5.0174
# Iteration: 720; Percent complete: 18.0%; Average loss: 5.1996
# Iteration: 721; Percent complete: 18.0%; Average loss: 5.5872
# Iteration: 722; Percent complete: 18.1%; Average loss: 5.3549
# Iteration: 723; Percent complete: 18.1%; Average loss: 5.0064
# Iteration: 724; Percent complete: 18.1%; Average loss: 5.2717
# Iteration: 725; Percent complete: 18.1%; Average loss: 5.1595
# Iteration: 726; Percent complete: 18.1%; Average loss: 5.0330
# Iteration: 727; Percent complete: 18.2%; Average loss: 5.2406
# Iteration: 728; Percent complete: 18.2%; Average loss: 5.3424
# Iteration: 729; Percent complete: 18.2%; Average loss: 5.2666
# Iteration: 730; Percent complete: 18.2%; Average loss: 5.3609
# Iteration: 731; Percent complete: 18.3%; Average loss: 5.2809
# Iteration: 732; Percent complete: 18.3%; Average loss: 5.1117
# Iteration: 733; Percent complete: 18.3%; Average loss: 5.3274
# Iteration: 734; Percent complete: 18.4%; Average loss: 5.1119
# Iteration: 735; Percent complete: 18.4%; Average loss: 5.4819
# Iteration: 736; Percent complete: 18.4%; Average loss: 4.8964
# Iteration: 737; Percent complete: 18.4%; Average loss: 5.2780
# Iteration: 738; Percent complete: 18.4%; Average loss: 5.1574
# ...
# Iteration: 3779; Percent complete: 94.5%; Average loss: 4.2326
# Iteration: 3780; Percent complete: 94.5%; Average loss: 4.3913
# Iteration: 3781; Percent complete: 94.5%; Average loss: 4.3895
# Iteration: 3782; Percent complete: 94.5%; Average loss: 4.2040
# Iteration: 3783; Percent complete: 94.6%; Average loss: 4.1525
# Iteration: 3784; Percent complete: 94.6%; Average loss: 4.3594
# Iteration: 3785; Percent complete: 94.6%; Average loss: 4.2980
# Iteration: 3786; Percent complete: 94.7%; Average loss: 4.3805
# Iteration: 3787; Percent complete: 94.7%; Average loss: 4.3378
# Iteration: 3788; Percent complete: 94.7%; Average loss: 4.1687
# Iteration: 3789; Percent complete: 94.7%; Average loss: 4.1982
# Iteration: 3790; Percent complete: 94.8%; Average loss: 4.2243
# Iteration: 3791; Percent complete: 94.8%; Average loss: 4.3844
# Iteration: 3792; Percent complete: 94.8%; Average loss: 4.2161
# Iteration: 3793; Percent complete: 94.8%; Average loss: 4.4003
# Iteration: 3794; Percent complete: 94.8%; Average loss: 4.2971
# Iteration: 3795; Percent complete: 94.9%; Average loss: 4.2652
# Iteration: 3796; Percent complete: 94.9%; Average loss: 4.3713
# Iteration: 3797; Percent complete: 94.9%; Average loss: 4.4638
# Iteration: 3798; Percent complete: 95.0%; Average loss: 4.2667
# Iteration: 3799; Percent complete: 95.0%; Average loss: 4.2549
# Iteration: 3800; Percent complete: 95.0%; Average loss: 4.3278
# Iteration: 3801; Percent complete: 95.0%; Average loss: 4.4563
# Iteration: 3802; Percent complete: 95.0%; Average loss: 4.1641
# Iteration: 3803; Percent complete: 95.1%; Average loss: 4.2967
# Iteration: 3804; Percent complete: 95.1%; Average loss: 4.1832
# Iteration: 3805; Percent complete: 95.1%; Average loss: 4.5905
# Iteration: 3806; Percent complete: 95.2%; Average loss: 4.3455
# Iteration: 3807; Percent complete: 95.2%; Average loss: 4.5183
# Iteration: 3808; Percent complete: 95.2%; Average loss: 4.6429
# Iteration: 3809; Percent complete: 95.2%; Average loss: 4.3013
# Iteration: 3810; Percent complete: 95.2%; Average loss: 4.3489
# Iteration: 3811; Percent complete: 95.3%; Average loss: 4.5145
# Iteration: 3812; Percent complete: 95.3%; Average loss: 4.1593
# Iteration: 3813; Percent complete: 95.3%; Average loss: 4.1392
# Iteration: 3814; Percent complete: 95.3%; Average loss: 4.2952
# Iteration: 3815; Percent complete: 95.4%; Average loss: 4.3706
# Iteration: 3816; Percent complete: 95.4%; Average loss: 4.6661
# Iteration: 3817; Percent complete: 95.4%; Average loss: 4.3077
# Iteration: 3818; Percent complete: 95.5%; Average loss: 4.2770
# Iteration: 3819; Percent complete: 95.5%; Average loss: 4.3206
# Iteration: 3820; Percent complete: 95.5%; Average loss: 4.5574
# Iteration: 3821; Percent complete: 95.5%; Average loss: 4.1265
# Iteration: 3822; Percent complete: 95.5%; Average loss: 3.9275
# Iteration: 3823; Percent complete: 95.6%; Average loss: 4.2990
# Iteration: 3824; Percent complete: 95.6%; Average loss: 4.1530
# Iteration: 3825; Percent complete: 95.6%; Average loss: 4.3083
# Iteration: 3826; Percent complete: 95.7%; Average loss: 4.3356
# Iteration: 3827; Percent complete: 95.7%; Average loss: 4.5768
# Iteration: 3828; Percent complete: 95.7%; Average loss: 4.2984
# Iteration: 3829; Percent complete: 95.7%; Average loss: 4.2894
# Iteration: 3830; Percent complete: 95.8%; Average loss: 4.4829
# Iteration: 3831; Percent complete: 95.8%; Average loss: 4.3062
# Iteration: 3832; Percent complete: 95.8%; Average loss: 4.2851
# Iteration: 3833; Percent complete: 95.8%; Average loss: 4.4836
# Iteration: 3834; Percent complete: 95.9%; Average loss: 4.4094
# Iteration: 3835; Percent complete: 95.9%; Average loss: 4.4037
# Iteration: 3836; Percent complete: 95.9%; Average loss: 4.1768
# Iteration: 3837; Percent complete: 95.9%; Average loss: 4.2594
# Iteration: 3838; Percent complete: 96.0%; Average loss: 4.2757
# Iteration: 3839; Percent complete: 96.0%; Average loss: 4.5036
# Iteration: 3840; Percent complete: 96.0%; Average loss: 4.3889
# Iteration: 3841; Percent complete: 96.0%; Average loss: 4.2144
# Iteration: 3842; Percent complete: 96.0%; Average loss: 4.1785
# Iteration: 3843; Percent complete: 96.1%; Average loss: 4.0875
# Iteration: 3844; Percent complete: 96.1%; Average loss: 4.2766
# Iteration: 3845; Percent complete: 96.1%; Average loss: 4.1139
# Iteration: 3846; Percent complete: 96.2%; Average loss: 4.2104
# Iteration: 3847; Percent complete: 96.2%; Average loss: 4.3404
# Iteration: 3848; Percent complete: 96.2%; Average loss: 4.3479
# Iteration: 3849; Percent complete: 96.2%; Average loss: 4.2241
# Iteration: 3850; Percent complete: 96.2%; Average loss: 4.3134
# Iteration: 3851; Percent complete: 96.3%; Average loss: 4.3033
# Iteration: 3852; Percent complete: 96.3%; Average loss: 4.2352
# Iteration: 3853; Percent complete: 96.3%; Average loss: 4.3380
# Iteration: 3854; Percent complete: 96.4%; Average loss: 4.2053
# Iteration: 3855; Percent complete: 96.4%; Average loss: 4.2161
# Iteration: 3856; Percent complete: 96.4%; Average loss: 4.2604
# Iteration: 3857; Percent complete: 96.4%; Average loss: 4.2697
# Iteration: 3858; Percent complete: 96.5%; Average loss: 4.1526
# Iteration: 3859; Percent complete: 96.5%; Average loss: 4.1088
# Iteration: 3860; Percent complete: 96.5%; Average loss: 4.4567
# Iteration: 3861; Percent complete: 96.5%; Average loss: 4.2945
# Iteration: 3862; Percent complete: 96.5%; Average loss: 4.3729
# Iteration: 3863; Percent complete: 96.6%; Average loss: 4.2651
# Iteration: 3864; Percent complete: 96.6%; Average loss: 4.1491
# Iteration: 3865; Percent complete: 96.6%; Average loss: 4.4868
# Iteration: 3866; Percent complete: 96.7%; Average loss: 4.3341
# Iteration: 3867; Percent complete: 96.7%; Average loss: 4.3157
# Iteration: 3868; Percent complete: 96.7%; Average loss: 4.0923
# Iteration: 3869; Percent complete: 96.7%; Average loss: 4.3714
# Iteration: 3870; Percent complete: 96.8%; Average loss: 4.3314
# Iteration: 3871; Percent complete: 96.8%; Average loss: 4.3389
# Iteration: 3872; Percent complete: 96.8%; Average loss: 4.4010
# Iteration: 3873; Percent complete: 96.8%; Average loss: 4.1082
# Iteration: 3874; Percent complete: 96.9%; Average loss: 4.2156
# Iteration: 3875; Percent complete: 96.9%; Average loss: 4.3492
# Iteration: 3876; Percent complete: 96.9%; Average loss: 4.3009
# Iteration: 3877; Percent complete: 96.9%; Average loss: 4.3632
# Iteration: 3878; Percent complete: 97.0%; Average loss: 4.3037
# Iteration: 3879; Percent complete: 97.0%; Average loss: 4.4801
# Iteration: 3880; Percent complete: 97.0%; Average loss: 4.1134
# Iteration: 3881; Percent complete: 97.0%; Average loss: 4.0816
# Iteration: 3882; Percent complete: 97.0%; Average loss: 4.4133
# Iteration: 3883; Percent complete: 97.1%; Average loss: 4.3104
# Iteration: 3884; Percent complete: 97.1%; Average loss: 4.2483
# Iteration: 3885; Percent complete: 97.1%; Average loss: 4.2508
# Iteration: 3886; Percent complete: 97.2%; Average loss: 4.3348
# Iteration: 3887; Percent complete: 97.2%; Average loss: 4.1771
# Iteration: 3888; Percent complete: 97.2%; Average loss: 4.2872
# Iteration: 3889; Percent complete: 97.2%; Average loss: 4.3612
# Iteration: 3890; Percent complete: 97.2%; Average loss: 4.3095
# Iteration: 3891; Percent complete: 97.3%; Average loss: 4.3748
# Iteration: 3892; Percent complete: 97.3%; Average loss: 4.2070
# Iteration: 3893; Percent complete: 97.3%; Average loss: 4.2430
# Iteration: 3894; Percent complete: 97.4%; Average loss: 4.1126
# Iteration: 3895; Percent complete: 97.4%; Average loss: 4.1825
# Iteration: 3896; Percent complete: 97.4%; Average loss: 4.4385
# Iteration: 3897; Percent complete: 97.4%; Average loss: 4.4379
# Iteration: 3898; Percent complete: 97.5%; Average loss: 4.3906
# Iteration: 3899; Percent complete: 97.5%; Average loss: 4.2479
# Iteration: 3900; Percent complete: 97.5%; Average loss: 4.3461
# Iteration: 3901; Percent complete: 97.5%; Average loss: 4.0941
# Iteration: 3902; Percent complete: 97.5%; Average loss: 4.1486
# Iteration: 3903; Percent complete: 97.6%; Average loss: 4.5651
# Iteration: 3904; Percent complete: 97.6%; Average loss: 4.4061
# Iteration: 3905; Percent complete: 97.6%; Average loss: 4.4964
# Iteration: 3906; Percent complete: 97.7%; Average loss: 4.4197
# Iteration: 3907; Percent complete: 97.7%; Average loss: 4.2097
# Iteration: 3908; Percent complete: 97.7%; Average loss: 4.4514
# Iteration: 3909; Percent complete: 97.7%; Average loss: 4.2873
# Iteration: 3910; Percent complete: 97.8%; Average loss: 4.4630
# Iteration: 3911; Percent complete: 97.8%; Average loss: 4.3448
# Iteration: 3912; Percent complete: 97.8%; Average loss: 4.3185
# Iteration: 3913; Percent complete: 97.8%; Average loss: 4.2217
# Iteration: 3914; Percent complete: 97.9%; Average loss: 4.0606
# Iteration: 3915; Percent complete: 97.9%; Average loss: 4.3225
# Iteration: 3916; Percent complete: 97.9%; Average loss: 4.1579
# Iteration: 3917; Percent complete: 97.9%; Average loss: 4.3868
# Iteration: 3918; Percent complete: 98.0%; Average loss: 4.3258
# Iteration: 3919; Percent complete: 98.0%; Average loss: 4.2949
# Iteration: 3920; Percent complete: 98.0%; Average loss: 4.4371
# Iteration: 3921; Percent complete: 98.0%; Average loss: 4.2767
# Iteration: 3922; Percent complete: 98.0%; Average loss: 4.3106
# Iteration: 3923; Percent complete: 98.1%; Average loss: 4.3678
# Iteration: 3924; Percent complete: 98.1%; Average loss: 4.1863
# Iteration: 3925; Percent complete: 98.1%; Average loss: 4.3761
# Iteration: 3926; Percent complete: 98.2%; Average loss: 4.3711
# Iteration: 3927; Percent complete: 98.2%; Average loss: 3.9439
# Iteration: 3928; Percent complete: 98.2%; Average loss: 4.2084
# Iteration: 3929; Percent complete: 98.2%; Average loss: 4.3149
# Iteration: 3930; Percent complete: 98.2%; Average loss: 4.4417
# Iteration: 3931; Percent complete: 98.3%; Average loss: 4.5699
# Iteration: 3932; Percent complete: 98.3%; Average loss: 4.3936
# Iteration: 3933; Percent complete: 98.3%; Average loss: 4.2404
# Iteration: 3934; Percent complete: 98.4%; Average loss: 4.2664
# Iteration: 3935; Percent complete: 98.4%; Average loss: 4.3565
# Iteration: 3936; Percent complete: 98.4%; Average loss: 4.5077
# Iteration: 3937; Percent complete: 98.4%; Average loss: 4.2013
# Iteration: 3938; Percent complete: 98.5%; Average loss: 4.4487
# Iteration: 3939; Percent complete: 98.5%; Average loss: 4.2358
# Iteration: 3940; Percent complete: 98.5%; Average loss: 4.1841
# Iteration: 3941; Percent complete: 98.5%; Average loss: 4.0091
# Iteration: 3942; Percent complete: 98.6%; Average loss: 4.4002
# Iteration: 3943; Percent complete: 98.6%; Average loss: 4.2685
# Iteration: 3944; Percent complete: 98.6%; Average loss: 4.0878
# Iteration: 3945; Percent complete: 98.6%; Average loss: 4.1344
# Iteration: 3946; Percent complete: 98.7%; Average loss: 4.3954
# Iteration: 3947; Percent complete: 98.7%; Average loss: 4.2638
# Iteration: 3948; Percent complete: 98.7%; Average loss: 4.3746
# Iteration: 3949; Percent complete: 98.7%; Average loss: 4.2747
# Iteration: 3950; Percent complete: 98.8%; Average loss: 4.4476
# Iteration: 3951; Percent complete: 98.8%; Average loss: 4.2752
# Iteration: 3952; Percent complete: 98.8%; Average loss: 4.1928
# Iteration: 3953; Percent complete: 98.8%; Average loss: 4.2383
# Iteration: 3954; Percent complete: 98.9%; Average loss: 4.1330
# Iteration: 3955; Percent complete: 98.9%; Average loss: 4.2995
# Iteration: 3956; Percent complete: 98.9%; Average loss: 4.4747
# Iteration: 3957; Percent complete: 98.9%; Average loss: 4.2457
# Iteration: 3958; Percent complete: 99.0%; Average loss: 4.2675
# Iteration: 3959; Percent complete: 99.0%; Average loss: 4.4526
# Iteration: 3960; Percent complete: 99.0%; Average loss: 4.4167
# Iteration: 3961; Percent complete: 99.0%; Average loss: 4.2165
# Iteration: 3962; Percent complete: 99.1%; Average loss: 4.4682
# Iteration: 3963; Percent complete: 99.1%; Average loss: 4.2518
# Iteration: 3964; Percent complete: 99.1%; Average loss: 4.3176
# Iteration: 3965; Percent complete: 99.1%; Average loss: 4.3545
# Iteration: 3966; Percent complete: 99.2%; Average loss: 4.0884
# Iteration: 3967; Percent complete: 99.2%; Average loss: 4.0461
# Iteration: 3968; Percent complete: 99.2%; Average loss: 4.3689
# Iteration: 3969; Percent complete: 99.2%; Average loss: 4.3519
# Iteration: 3970; Percent complete: 99.2%; Average loss: 4.2531
# Iteration: 3971; Percent complete: 99.3%; Average loss: 4.1927
# Iteration: 3972; Percent complete: 99.3%; Average loss: 4.1563
# Iteration: 3973; Percent complete: 99.3%; Average loss: 4.4135
# Iteration: 3974; Percent complete: 99.4%; Average loss: 4.3901
# Iteration: 3975; Percent complete: 99.4%; Average loss: 4.4240
# Iteration: 3976; Percent complete: 99.4%; Average loss: 4.1532
# Iteration: 3977; Percent complete: 99.4%; Average loss: 4.2817
# Iteration: 3978; Percent complete: 99.5%; Average loss: 4.0208
# Iteration: 3979; Percent complete: 99.5%; Average loss: 4.1789
# Iteration: 3980; Percent complete: 99.5%; Average loss: 4.1796
# Iteration: 3981; Percent complete: 99.5%; Average loss: 4.3899
# Iteration: 3982; Percent complete: 99.6%; Average loss: 4.5780
# Iteration: 3983; Percent complete: 99.6%; Average loss: 4.3443
# Iteration: 3984; Percent complete: 99.6%; Average loss: 4.1635
# Iteration: 3985; Percent complete: 99.6%; Average loss: 4.1183
# Iteration: 3986; Percent complete: 99.7%; Average loss: 4.2669
# Iteration: 3987; Percent complete: 99.7%; Average loss: 4.2552
# Iteration: 3988; Percent complete: 99.7%; Average loss: 4.2824
# Iteration: 3989; Percent complete: 99.7%; Average loss: 4.2128
# Iteration: 3990; Percent complete: 99.8%; Average loss: 4.3024
# Iteration: 3991; Percent complete: 99.8%; Average loss: 4.1638
# Iteration: 3992; Percent complete: 99.8%; Average loss: 4.4060
# Iteration: 3993; Percent complete: 99.8%; Average loss: 4.3262
# Iteration: 3994; Percent complete: 99.9%; Average loss: 4.3694
# Iteration: 3995; Percent complete: 99.9%; Average loss: 4.2593
# Iteration: 3996; Percent complete: 99.9%; Average loss: 4.4251
# Iteration: 3997; Percent complete: 99.9%; Average loss: 4.3682
# Iteration: 3998; Percent complete: 100.0%; Average loss: 4.3572
# Iteration: 3999; Percent complete: 100.0%; Average loss: 4.2560
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.2154
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Clip</td><td>▁</td></tr><tr><td>Decoder Learning Ratio</td><td>▁</td></tr><tr><td>Iteration</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>Learning Rate</td><td>▁</td></tr><tr><td>Loss</td><td>▄▄▄▃▅▇▃▄▇█▇▁▅▄▆▆▄▃▆▅▂▅▅▂▇█▇▂▆▄▇▅▂▆▆▆▄▃▇▅</td></tr><tr><td>Teacher Forcing Ratio</td><td>▁</td></tr><tr><td>loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Clip</td><td>0</td></tr><tr><td>Decoder Learning Ratio</td><td>10</td></tr><tr><td>Iteration</td><td>4000</td></tr><tr><td>Learning Rate</td><td>0.0005</td></tr><tr><td>Loss</td><td>4.21535</td></tr><tr><td>Optimizer</td><td>adam</td></tr><tr><td>Teacher Forcing Ratio</td><td>1</td></tr><tr><td>loss</td><td>4.21535</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-16</strong> at: <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/runs/hpt8n04x' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6/runs/hpt8n04x</a><br> View project at: <a href='https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6' target="_blank">https://wandb.ai/youjie020726-new-york-university/chatbot_sweep_profiler6</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 8 other file(s)
# Find logs at: <code>./wandb/run-20250313_060003-hpt8n04x/logs</code>

# %%
#

def trainIters_profiler(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers,
               decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename, teacher_forcing_ratio):

    config = wandb.config
    wandb.log({
        "Learning Rate": config.learning_rate,
        "Decoder Learning Ratio": config.decoder_learning_ratio,
        "Clip": config.clip,
        "Teacher Forcing Ratio": config.teacher_forcing_ratio,
        "Optimizer": config.optimizer,
    })

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    with profile(
                activities=[ProfilerActivity.CPU, torch.profiler.ProfilerActivity.CUDA],
                schedule=torch.profiler.schedule(wait=2, warmup=2, active=3, repeat=1),
                on_trace_ready=torch.profiler.tensorboard_trace_handler('./profiler_logs'),
                # profile_memory=True,
                record_shapes=True,
                with_stack=True
            ) as prof:
    # Training loop
        print("Training...")
        for iteration in range(start_iteration, n_iteration + 1):
            training_batch = training_batches[iteration - 1]
            # Extract fields from batch
            input_variable, lengths, target_variable, mask, max_target_len = training_batch

            # Run a training iteration with batch
            loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                        decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip, teacher_forcing_ratio)
            print_loss += loss

            # Print progress
            if iteration % print_every == 0:
                print_loss_avg = print_loss / print_every
                print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))

                wandb.log({
                    "Iteration": iteration,
                    "Loss": print_loss_avg})

                print_loss = 0
                prof.step()

            # Save checkpoint
            if (iteration % save_every == 0):
                directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
                if not os.path.exists(directory):
                    os.makedirs(directory)

                checkpoint_path = os.path.join(directory, f'{iteration}_checkpoint.tar')

                torch.save({
                    'iteration': iteration,
                    'en': encoder.state_dict(),
                    'de': decoder.state_dict(),
                    'en_opt': encoder_optimizer.state_dict(),
                    'de_opt': decoder_optimizer.state_dict(),
                    'loss': loss,
                    'voc_dict': voc.__dict__,
                    'embedding': embedding.state_dict()
                }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

                wandb.save(checkpoint_path)
        print(prof.key_averages().table(sort_by="self_cpu_memory_usage", row_limit=10))
        wandb.log({"loss": print_loss_avg})

        # prof.export_chrome_trace("trace1.json")
        print("Profiling complete. JSON trace file saved as 'trace.json'")

# %%
n_iteration = 15
print_every = 1
save_every = 500

encoder.train()
decoder.train()

def train_sweep_profiler():
    wandb.init()
    config = wandb.config

    clip = config.clip
    teacher_forcing_ratio = config.teacher_forcing_ratio
    learning_rate = config.learning_rate
    decoder_learning_ratio = config.decoder_learning_ratio
    optimizer_type = config.optimizer

    if optimizer_type == "adam":
        encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
        decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
    elif optimizer_type == "sgd":
        encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
        decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)

    if loadFilename:
        encoder_optimizer.load_state_dict(encoder_optimizer_sd)
        decoder_optimizer.load_state_dict(decoder_optimizer_sd)

    for state in encoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)

    for state in decoder_optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)

    print(f"Starting Training with {optimizer_type.upper()} optimizer!")
    trainIters_profiler(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
               embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
               print_every, save_every, clip, corpus_name, loadFilename, teacher_forcing_ratio)


wandb.agent(sweep_id, function=train_sweep_profiler, count=1)

# %%
pip install torch_tb_profiler

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir /content/profiler_logs

# %% [markdown]
# Conclusion
# ==========
#
# That's all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you're
# interested, you can try tailoring the chatbot's behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!
